# %%
asdfasdfasdfafd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-604017779c36> in <cell line: 1>()
# ----> 1 asdfasdfasdfafd
#
# NameError: name 'asdfasdfasdfafd' is not defined
